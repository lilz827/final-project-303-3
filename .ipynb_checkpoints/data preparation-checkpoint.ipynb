# %%
import pandas as pd
import numpy as np

# %%
stats = pd.read_csv('CollegeBasketballPlayers2009-2021.csv')
draft = pd.read_csv('DraftedPlayers2009-2021.csv')
# Out:
# /var/folders/gx/rnh895q11cb5zsdbh368424h0000gn/T/ipykernel_73287/2647321993.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   stats = pd.read_csv('CollegeBasketballPlayers2009-2021.csv')

# %%
print(stats['pick'].isnull().sum())
print(stats['dunksmade/(dunksmade+dunksmiss)'].isnull().sum())
print(stats['midmade/(midmade+midmiss)'].isnull().sum())
print(stats['rimmade/(rimmade+rimmiss)'].isnull().sum())
print(stats['Rec Rank'].isnull().sum())
# Out:
# 59626
# 33510
# 10385
# 10110
# 42591

# %%
#dropping columns with more than 10,000 missing values 
stats_2 = stats.drop(columns = ['pick','dunksmade/(dunksmade+dunksmiss)','midmade/(midmade+midmiss)','rimmade/(rimmade+rimmiss)', 'Rec Rank'])

# %%
stats_no_missing = stats_2.dropna()
stats_no_missing
# Out:
#               player_name               team  conf  GP  Min_per   Ortg   usg  \
# 4589        Pooh Williams           Utah St.   WAC  32     64.0  108.3  18.1
# 4590         Nick Rodgers             Butler  Horz  11      1.0  121.1  16.8
# 4591           Dana Smith           Longwood   ind  27     81.8   99.8  27.7
# 4594        Carlos Strong  Boston University    AE  35     76.2  118.1  16.4
# 4595        Sherrod Smith  Boston University    AE  29      9.5   60.7   6.9
# ...                   ...                ...   ...  ..      ...    ...   ...
# 61046         David Jones             DePaul    BE   9     17.1   86.9  21.8
# 61047         Mac Etienne               UCLA   P12  13     11.0   99.1  15.1
# 61050  Lysander Rehnstrom       George Mason   A10   2      0.3    0.0  32.2
# 61051          Trey James               Iona  MAAC   2      0.8   45.9  29.9
# 61057  Stavros Polatoglou   Northwestern St.  Slnd   4      1.3   28.3   7.1
#
#         eFG  TS_per  ORB_per  ...      dgbpm    oreb    dreb    treb     ast  \
# 4589   53.0   53.33      2.3  ...   0.276271  0.4688  1.3750  1.8438  2.1875
# 4590   75.0   75.00      0.0  ...  -0.514877  0.0000  0.0000  0.0000  0.0909
# 4591   49.9   53.76      6.9  ...  -2.067400  2.1481  4.9259  7.0741  2.4074
# 4594   58.8   60.93      4.7  ...   2.338340  1.3429  3.2286  4.5714  1.8000
# 4595    8.3   14.93      3.2  ...   0.924890  0.1379  0.5862  0.7241  0.2069
# ...     ...     ...      ...  ...        ...     ...     ...     ...     ...
# 61046  39.1   40.09      7.3  ...   0.529388  1.0000  1.6667  2.6667  0.4444
# 61047  60.0   55.37     10.2  ...   0.799673  0.9231  1.9231  2.8462  0.2308
# 61050   0.0    0.00      0.0  ... -13.826600  0.0000  0.0000  0.0000  0.0000
# 61051   0.0   52.63     19.8  ...  -5.286060  0.5000  0.5000  1.0000  0.0000
# 61057   0.0    0.00      7.0  ...  -4.993820  0.2500  0.0000  0.2500  0.0000
#
#           stl     blk      pts  Unnamed: 64  Unnamed: 65
# 4589   0.5938  0.2188   8.7812      Combo G     7.300850
# 4590   0.0000  0.0000   0.5455      Pure PG    12.267400
# 4591   0.8148  0.4815  17.5556       Wing F     5.581250
# 4594   1.6571  0.4000  10.8571      Combo G     6.583070
# 4595   0.1034  0.0345   0.1724       Wing G     0.844851
# ...       ...     ...      ...          ...          ...
# 61046  0.4444  0.2222   5.1111       Wing F     6.045190
# 61047  0.1538  0.1538   2.6154            C     0.000000
# 61050  0.0000  0.0000   0.0000         PF/C    22.228300
# 61051  0.0000  0.0000   0.5000            C     0.000000
# 61057  0.0000  0.0000   0.0000            C     0.000000
#
# [51376 rows x 61 columns]

# %%
year_sorted = stats_2.sort_values(by='year')
#keep only most recent instance with duplicate name entries
stats_unique = year_sorted.drop_duplicates(subset='player_name', keep='last')

# %%
stats_unique_no_missing = stats_filtered.dropna()

stats_unique_no_missing
# Out:
#             player_name              team  conf  GP  Min_per   Ortg   usg  \
# 7718       Mason Felter       Wichita St.   MVC   7      2.3   55.8  18.4
# 7716     Atakan Yurttas       McNeese St.  Slnd   5      0.9  126.3  28.6
# 7711         Jay Kinney              Ohio   MAC  19     29.0   97.8  22.5
# 7727   Terrance Coleman  Tennessee Martin   OVC  27     42.2   81.2  17.8
# 7728    Elliot Williams           Memphis  CUSA  34     83.3  112.8  27.7
# ...                 ...               ...   ...  ..      ...    ...   ...
# 57745   Khaleem Bennett  Central Arkansas  Slnd  20     53.9   86.7  21.9
# 57744      Caleb Broodo           Houston  Amer   3      0.4  138.8  20.3
# 57743    Ron Harper Jr.           Rutgers   B10  27     76.7  109.1  22.6
# 57742   Jalen Jefferson  Mount St. Mary's   NEC  12      6.7  107.0  10.2
# 57749      Assane Diouf        Fresno St.   MWC   5      1.2    0.0  12.9
#
#          eFG  TS_per  ORB_per  ...     dgbpm    oreb    dreb    treb     ast  \
# 7718    20.0   25.21     15.6  ...  0.611826  0.5714  0.5714  1.1429  0.1429
# 7716   100.0   77.92     11.1  ...  2.459910  0.2000  0.0000  0.2000  0.2000
# 7711    49.1   50.83      0.8  ... -0.247611  0.1579  1.3684  1.5263  1.5263
# 7727    33.3   37.84      9.3  ... -3.746650  1.5556  1.2593  2.8148  0.6667
# 7728    53.6   59.85      2.7  ...  0.191424  0.7353  3.2353  3.9706  3.7647
# ...      ...     ...      ...  ...       ...     ...     ...     ...     ...
# 57745   43.3   48.62      7.5  ... -3.056310  1.5714  2.2381  3.8095  1.0952
# 57744    0.0   51.28     22.1  ... -3.127640  0.5000  0.5000  1.0000  0.2500
# 57743   50.9   53.85      3.5  ...  1.342070  1.0000  4.8519  5.8519  1.5556
# 57742   66.7   69.62      7.7  ... -0.290050  0.3333  0.9167  1.2500  0.0000
# 57749    0.0    0.00      0.0  ... -3.859400  0.0000  0.3333  0.3333  0.0000
#
#           stl     blk      pts  Unnamed: 64  Unnamed: 65
# 7718   0.1429  0.2857   0.4286            C      1.94816
# 7716   0.2000  0.0000   1.2000      Pure PG      0.00000
# 7711   0.7895  0.1579   9.7368      Combo G     13.04940
# 7727   0.3333  0.1111   3.9630       Wing G      4.19935
# 7728   1.3235  0.1176  17.9412      Combo G      8.57340
# ...       ...     ...      ...          ...          ...
# 57745  0.6190  0.4286   8.7143       Wing G      1.41980
# 57744  0.0000  0.0000   1.0000            C      0.00000
# 57743  0.6667  0.6667  14.8519       Wing F      9.86760
# 57742  0.0833  0.0000   0.9167         PF/C      0.00000
# 57749  0.0000  0.1667   0.3333            C      0.00000
#
# [21260 rows x 61 columns]
